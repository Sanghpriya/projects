# %%
import geopandas as gpd

# Load districts (level 2 = districts)
india_districts = gpd.read_file("F:\landslide\gadm41_IND_shp\gadm41_IND_2.shp")

# Filter Tehri Garhwal
tehri = india_districts[india_districts["NAME_2"] == "Tehri Garhwal"]

# Save for reuse
tehri.to_file("tehri_boundary.shp")

print(tehri)
# Out:
#            GID_2 GID_0 COUNTRY     GID_1       NAME_1 NL_NAME_1  \
# 652  IND.35.11_1   IND   India  IND.35_1  Uttarakhand        NA
#
#             NAME_2                         VARNAME_2 NL_NAME_2    TYPE_2  \
# 652  Tehri Garhwal  Tehri|Narendranagar|Tehri Garwal        NA  District
#
#     ENGTYPE_2 CC_2    HASC_2  \
# 652  District   NA  IN.UT.TG
#
#                                               geometry
# 652  POLYGON ((78.28455 30.1257, 78.27177 30.13, 78...
